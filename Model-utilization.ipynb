# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("EDA.csv")

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.head(50)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0             6      148             87             35      156   33
# 1             1       85             87             29      156   26
# 2             8      183             87             29      156   23
# 3             1       89             87             23       94   28
# 4             0      137             87             35      168   43
# 5             5      116             87             29      156   25
# 6             3       78             87             32       88   31
# 7            10      115             87             29      156   35
# 8             2      197             87             45      543   30
# 9             8      125             96             29      156   32
# 10            4      110             92             29      156   37
# 11           10      168             87             29      156   38
# 12           10      139             80             29      156   27
# ...

# %%
preg=int(input("Enter your pregnancy count:-"))
glu=int(input("Enter your Glucose count:-"))
bp=int(input("Enter your BloodPressure count:-"))
st=int(input("Enter your SkinThickness count:-"))
ins=int(input("Enter your Insulin count:-"))
bmi=int(input("Enter your BMI count:-"))
dpf=float(input("Enter your DiabetesPedigreeFunction count:-"))
age=int(input("Enter your Age :-"))
# Out:
# Enter your pregnancy count:- 1
# Enter your Glucose count:- 32
# Enter your BloodPressure count:- 125
# Enter your SkinThickness count:- 12
# Enter your Insulin count:- 39
# Enter your BMI count:- 45
# Enter your DiabetesPedigreeFunction count:- 0.458
# Enter your Age :- 21

# %%
columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI','DiabetesPedigreeFunction', 'Age']
data=[[preg,glu,bp,st,ins,bmi,dpf,age]]

# %%
myinput=pd.DataFrame(data=data,columns=columns)
myinput
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            1       32            125             12       39   45
#
#    DiabetesPedigreeFunction  Age
# 0                     0.458   21

# %%
pipe=pkl.load(open("Diabeties-Prediction.pkl","rb+"))
result=pipe.predict(myinput)
print(result[0].round())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 pipe=pkl.load(open("Diabeties-Prediction.pkl","rb+"))
#       2 result=pipe.predict(myinput)
#       3 print(result[0].round())
#
# NameError: name 'pkl' is not defined
